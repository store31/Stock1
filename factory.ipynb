# %% [markdown]
# <a href="https://colab.research.google.com/github/store31/Stock1/blob/main/factory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# تثبيت الأدوات (هادي ديرها مرة وحدة برك)
# !pip install diffusers transformers accelerate edge-tts
# !apt-get install ffmpeg -y

import torch
from diffusers import StableDiffusionPipeline
import edge_tts
import asyncio
import os

# تحميل Stable Diffusion للجودة الأمريكية
print("🚀 تحميل المحرك...")
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
print("✅ المحرك جاهز!")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 🚀 تحميل المحرك...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
await make_us_video("The future of AI is here", "Futuristic neon city")
# Out:
# 🎙️ يصنع في الصوت الأمريكي...
# 🎨 يرسم في الصورة (T4 GPU)...
#   0%|          | 0/50 [00:00<?, ?it/s]
# 🎬 المونتاج النهائي...
# ✅ الفيديو واجد باسم: video_final.mp4
